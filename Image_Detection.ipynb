# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajababuray/Data_Science/blob/main/Image_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-192-g459dd49 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 24.2/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# To unzip the Train_data.zip file
#!unzip -q ../Train_data.zip -d ../
# Out:
# unzip:  cannot find or open ../Train_data.zip, ../Train_data.zip.zip or ../Train_data.zip.ZIP.

# %%
# Train YOLOv5s on custom_datafor 3 epochs
# !python train.py --img 640 --batch 16 --epochs 5000 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=5000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-192-g459dd49 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/last.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/full/video.mp4
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (9957/14954) /content/drive/MyDrive/full/video.mp4: 384x640 9 Madagascar periwinkles, 7.7ms
# video 1/1 (9958/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9959/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9960/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9961/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9962/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9963/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9964/14954) /content/drive/MyDrive/full/video.mp4: 384x640 10 Madagascar periwinkles, 7.7ms
# video 1/1 (9965/14954) /content/drive/MyDrive/full/video.mp4: 384x640 11 Madagascar periwinkles, 7.7ms
# ...
